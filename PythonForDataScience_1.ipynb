# %% [markdown]
# <a href="https://colab.research.google.com/github/LegendTejas/PythonForDataScience/blob/main/PythonForDataScience_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Data Science**
#
# ###*Skills Required to Become a Data Scientist*
#
# To become a successful **Data Scientist**, you need a blend of **technical**, **analytical**, and **soft skills**. Here's a categorized overview:
#
# ---
#
# ### 🔹 1. Programming Skills
#
# - ✅ **Python** (most preferred) or **R**
# - ✅ Libraries: `NumPy`, `Pandas`, `Matplotlib`, `Seaborn`, `Scikit-learn`, `TensorFlow`, `PyTorch`
# - ✅ Use of **Jupyter Notebooks** or **Google Colab**
#
# ---
#
# ### 🔹 2. Mathematics & Statistics
#
# - 📊 **Statistics**: Mean, Median, Mode, Variance, Probability, Hypothesis Testing
# - 🧠 **Linear Algebra**: Vectors, Matrices, Eigenvalues (especially for ML & Deep Learning)
# - 📈 **Calculus**: Derivatives and gradients (for model optimization)
#
# ---
#
# ### 🔹 3. Data Manipulation & Analysis
#
# - 🔍 **Pandas**: DataFrames, filtering, grouping
# - 📉 **Exploratory Data Analysis (EDA)**: Summarizing datasets, identifying patterns
# - 📌 **Handling Missing Data, Outliers, and Duplicates**
#
# ---
#
# ### 🔹 4. Data Visualization
#
# - 📊 **Matplotlib**, **Seaborn**, **Plotly**
# - 📍 Ability to create:
#   - Histograms, Boxplots
#   - Heatmaps, Scatter plots
#   - Dashboards (using `Streamlit` or `Power BI`)
#
# ---
#
# ### 🔹 5. Machine Learning
#
# - 🧠 Supervised & Unsupervised Learning
# - 🛠 Algorithms:
#   - Regression, Classification (Logistic, Decision Trees, SVM)
#   - Clustering (K-Means, DBSCAN)
#   - Ensemble Methods (Random Forest, XGBoost)
# - 🧪 Model Evaluation: Accuracy, Precision, Recall, F1-Score, ROC AUC
#
# ---
#
# ### 🔹 6. Deep Learning (Advanced)
#
# - 🔗 Neural Networks, CNNs, RNNs, Transfer Learning
# - 🔧 Frameworks: TensorFlow, Keras, PyTorch
#
# ---
#
# ### 🔹 7. SQL and Databases
#
# - 🗃 **SQL**: Select, Join, GroupBy, Subqueries
# - 🧮 Basic understanding of **relational databases** and **NoSQL** (e.g., MongoDB)
#
# ---
#
# ### 🔹 8. Big Data Tools (Advanced)
#
# - 🧰 Hadoop, Spark, Hive, Kafka (for handling large datasets)
#
# ---
#
# ### 🔹 9. Cloud & Deployment
#
# - ☁️ Platforms: AWS, GCP, Azure
# - 🚀 Deploy models using:
#   - Flask/Django APIs
#   - Streamlit for live dashboards
#   - Docker (for containerization)
#
# ---
#
# ### 🔹 10. Soft Skills & Business Acumen
#
# - 💡 **Critical Thinking**: Ask the right questions
# - 🎯 **Problem-Solving**: Understand root causes
# - 📢 **Communication**: Explain findings clearly to non-technical stakeholders
# - 💼 **Domain Knowledge**: Understanding of the industry (finance, health, etc.)
#
# ---
#
# #### 🌱 Bonus: Tools & Practices
#
# - 🧪 Version Control: `Git`, GitHub
# - 📈 Experiment tracking: `MLflow`, `Weights & Biases`
# - 📚 Continuous Learning: Stay updated via blogs, research papers, Kaggle
#
# ---
#
#
# ##**Introduction to Python for Data Science**
#
# Python is one of the most popular and powerful programming languages in the field of Data Science due to its:
#
# Simplicity and readability
#
# Rich ecosystem of libraries
#
# Strong community support
#
# Data Science involves extracting insights from structured or unstructured data using techniques from statistics, machine learning, and data visualization — and Python supports every stage of this workflow.
#
#
# ##**Why Python for Data Science?**
#
# 1. Easy to Learn: Python’s syntax is beginner-friendly.
#
# 2. Versatile Libraries:
#
#   * `NumPy`: Fast numerical computations
#
#   * `Pandas`: Data manipulation and analysis
#
#   * `Matplotlib` / `Seaborn`: Data visualization
#
#   * `Scikit-learn`: Machine learning
#
#   * `TensorFlow` / `PyTorch`: Deep learning
#
# 3. Integration: Works well with SQL, APIs, Big Data tools, and cloud services.
#
# 4. Jupyter Notebooks/ Google Colab: Ideal for writing, testing, and sharing data science code interactively.
#
#
# ##**Typical Data Science Workflow in Python**
#
# **1. Data Collection**
# * From CSVs, Excel, Databases, APIs, Web scraping
#
# **2. Data Cleaning**
# * Handle missing values, remove duplicates, format data
#
# **3. Exploratory Data Analysis (EDA)**
# * Summary statistics, correlations, visualizations
#
# **4. Feature Engineering**
# * Transform raw data into usable features for models
#
# **5. Model Building**
# * Use libraries like `scikit-learn` for regression, classification, clustering
#
# **6. Evaluation & Tuning**
# * Test accuracy, precision, recall, use cross-validation
#
# **7. Deployment and Visualization**
# * Deploy using `Flask`, `Streamlit`, or cloud platforms; visualize using `matplotlib`, `plotly`, or dashboards

# %% [markdown]
# A Sample Python Code Snippet:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv('titanic.csv')

# Basic EDA
print(df.describe())
print(df.isnull().sum())

# Visualization
sns.histplot(df['Age'], kde=True)
plt.title("Age Distribution")
plt.show()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# ...

# %% [markdown]
# ###Problem Solving
#
# **Problem1:**
# Given a list of numbers i.e [1,4,2,-5,9,7,3,2], make another list that contains all items in sorted order i.e [-5,1,2,2,3,4,7,9]

# %% [markdown]
# Approach: Selection Sort where first we will find th minimum value and swap it with the first value

# %%
L =  [1,4,2,-5,9,7,3,2]
min_val = L[0]
idx = 0
count = 0
for i in L:
  if i < min_val:
    min_val = i
    idx = count
  count += 1
print(f"Minimum Value: {min_val} is found at index {idx}")
# Out:
# Minimum Value: -5 is found at index 3

# %%
temp = L[0]
L[0] = min_val
L[idx] = temp
print(L) #Now the minimum value is swapped with the first value
# Out:
# [-5, 4, 2, 1, 9, 7, 3, 2]

# %%
L =  [1,4,2,-5,9,7,3,2]
for j in range(len(L)):
  min_val = L[j]
  idx = j
  count = j

  for i in range(j,len(L)):
    if L[i] < min_val:
      min_val = L[i]
      idx = count
    count += 1

  temp = L[j]
  L[j] = min_val
  L[idx] = temp

print(L) #Sorted List
# Out:
# [-5, 1, 2, 2, 3, 4, 7, 9]

# %% [markdown]
# ###Functions and Recursion

# %%
def greet(name):
    """
    This function takes a name as input and returns a greeting string.

    Parameters:
    name (str): The name of the person.

    Returns:
    str: Greeting message.
    """
    print(f"Hello, {name}!")

#A docstring (short for documentation string) is a special type of string literal
# used in Python to document code — such as functions, classes, or modules.

# %% [markdown]
# **Key Points**
# * Triple quotes (" " " ..... " " " or ' ' ' ..... ' ' ') are used for docstrings.
#
# * The docstring should be the first statement inside a function/class/module.
#
# * You can access it using:
# `print(greet.__doc__)`
#
# * Writing a docstring inside a function, class or modules is a good practice

# %%
greet? #DocString

# Signature: greet(name)
# Docstring:
# This function takes a name as input and returns a greeting string.

# Parameters:
# name (str): The name of the person.

# Returns:
# str: Greeting message.
# File:      /tmp/ipython-input-14-3695656060.py
# Type:      function

# %%
greet?? #DocString along with whole implementation

# Signature: greet(name)
# Source:
# def greet(name):
#     """
#     This function takes a name as input and returns a greeting string.

#     Parameters:
#     name (str): The name of the person.

#     Returns:
#     str: Greeting message.
#     """
#     print(f"Hello, {name}!")
# File:      /tmp/ipython-input-14-3695656060.py
# Type:      function

# %%
def printMsg(msg):
    """
    Prints the given message if it is a string.

    Parameters:
    msg (any): The message to be printed.

    If the input is not a string, it prints an error message
    along with the actual data type of the input.
    """
    if isinstance(msg, str):
        print(msg)
    else:
        print("Your input is not a string")
        print("Here is the type of what you have supplied:", type(msg))

# %%
print(printMsg.__doc__)
# Out:
#     Prints the given message if it is a string.
#
#     Parameters:
#     msg (any): The message to be printed.
#
#     If the input is not a string, it prints an error message
#     along with the actual data type of the input.

# %%
printMsg("This is the message")
# Out:
# This is the message

# %%
printMsg(234)
# Out:
# Your input is not a string
# Here is the type of what you have supplied: <class 'int'>

# %%
y = "Hello There, Tejas Here!"
printMsg(y)
# Out:
# Hello There, Tejas Here!

# %%
def mypow(a, b):
  """ This function computes power
      just like built-in pow() function
  """
  c = a**b
  print(c)

# %%
mypow(3,4)
# Out:
# 81

# %% [markdown]
# Iterative Method for power of two

# %%
def myPow(x: float, n: int) -> float:
    if n == 0:
        return 1
    if n < 0:
        x = 1 / x
        n = -n

    result = 1
    while n > 0:
        if n % 2 == 1:
            result *= x
        x *= x
        n //= 2
    return result
a = 3
b = 4
print(myPow(a,b))
# Out:
# 81

# %% [markdown]
# Recursive Method for power of two

# %%
def myPow(x: float, n: int) -> float:
    def power(x, n):
        if n == 0:
            return 1
        half = power(x, n // 2)
        return half * half if n % 2 == 0 else half * half * x

    if n < 0:
        x = 1 / x
        n = -n
    return power(x, n)
a = 3
b = 4
print(myPow(a,b))
# Out:
# 81

# %%
def checkArgs(a, b, c):
  """Prints the square of the sum if all inputs are int or float,
     else shows an error."""

  if isinstance(a,(int,float)) and isinstance(b,(int,float)) and isinstance(c, (int,float)):
    print((a+b+c)**2)
  else:
    print("Error: The input arguments are not of the expected types")

# %%
checkArgs(1,2,"g")
# Out:
# Error: The input arguments are not of the expected types

# %%
checkArgs(4,5,2)
# Out:
# 121

# %% [markdown]
# Function(return statement)
#
# The return statement in a function is used to send a result back to where the function was called. It ends the function and gives back a value.

# %%
def add(a, b):
    return a + b

result = add(2, 3)
print(result)
# Out:
# 5

# %% [markdown]
# Here, `return a + b` gives the sum to the caller. Without `return`, the function would do the work but not give any output back.
#
# By using return statement you can access function outside the function.

# %%
add(3,4)
# Out:
# 7

# %%
variable_outside_the_function = 3 #gloabal variable

# %%
def g():
  variable_outside_the_function = 5 #local variable
  print(variable_outside_the_function)

# %%
g()
# Out:
# 5

# %%
print(variable_outside_the_function)
# Out:
# 3

# %% [markdown]
# **Arbitrary Number of Input Arguments in Python Functions**
#
# In Python, you can create functions that accept any number of arguments using:
#
# 1. `*args` for **non-keyword(positional) arguments**
#
# 2. `*kwargs` for **keyword arguments**

# %% [markdown]
# ###**1. *args – Arbitrary Positional Arguments**
#
# * Allows a function to accept any number of positional arguments.
#
# * Inside the function, args is a tuple.

# %%
#Syntax:
def function_name(*args):
    # args is a tuple of all positional arguments
    pass

# %%
def mySum(*args):
  sum = 0
  for i in range(len(args)):
    sum += args[i]
  return sum

# %%
mySum(4,3,2,1)
# Out:
# 10

# %%
mySum(2,9,5,5.9,78)
# Out:
# 99.9

# %% [markdown]
# ###**2. **kwargs – Arbitrary Keyword Arguments**
#
# * Allows a function to accept any number of keyword arguments.
#
# * Inside the function, kwargs is a dictionary.

# %%
#Syntax:
def function_name(**kwargs):
    # kwargs is a dictionary of all keyword arguments
    pass

# %%
def AllVar(**kwargs):
  for x in kwargs:
    print("Variable Name is: ",x," And Value is: ",kwargs[x])

# %%
AllVar(a = 3, b = "B", c = "CCC", y = 6.7)
# Out:
# Variable Name is:  a  And Value is:  3
# Variable Name is:  b  And Value is:  B
# Variable Name is:  c  And Value is:  CCC
# Variable Name is:  y  And Value is:  6.7

# %%
def print_info(**kwargs):
    for key, value in kwargs.items():
        print(f"{key}: {value}")

print_info(name="Teju", age=21, country="India")
# Out:
# name: Teju
# age: 21
# country: India

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def demo(a, *args, **kwargs):
    print(f"First arg: {a}")
    print(f"Other positional args: {args}")
    print(f"Keyword args: {kwargs}")

demo(1, 2, 3, x=10, y=20)
# Out:
# First arg: 1
# Other positional args: (2, 3)
# Keyword args: {'x': 10, 'y': 20}

# %% [markdown]
# Functions (Default Values)

# %%
def func(sum = 0):
  print(sum)

# %%
func()
# Out:
# 0

# %%
func(56)
# Out:
# 56

# %%
li = [1,2,3]
li2 = li
li2[0] = -9
print(li)
# Out:
# [-9, 2, 3]

# %%
def f(li = [1,2]):
  for i in li:
    print(i)

# %%
li2 = [12,3,4]
f() #no arguments passed so default value [1,2] will be printed
# Out:
# 1
# 2

# %%
f(li2) #argument li2 is passed
# Out:
# 12
# 3
# 4

# %% [markdown]
# ###**Modules**
# A module in Python is simply a file containing Python code (functions, variables, classes) that you can reuse in other programs by importing it.
#
# ###Types of Modules:
# * Built-in modules – Already included in Python (e.g., `math`, `random`, `datetime`)
#
# * User-defined modules – Created by you (e.g., `my_utils.py`)
#
# * External modules – Installed via pip (e.g., `numpy`, `pandas`, `requests`)
#
# | Module     | Use Case                     |
# | ---------- | ---------------------------- |
# | `math`     | Mathematical functions       |
# | `random`   | Random number generation     |
# | `datetime` | Date and time handling       |
# | `os`       | Operating system interaction |
# | `sys`      | System-specific functions    |
# | `json`     | Working with JSON data       |
# | `re`       | Regular expressions          |

# %% [markdown]
# ###How to Use a Module?

# %% [markdown]
# 1. Importing a built-in module:

# %%
import math
print(math.sqrt(16))  # Output: 4.0
# Out:
# 4.0

# %% [markdown]
# 2. Importing specific functions:

# %%
from math import sqrt, pi
print(sqrt(25))   # 5.0
print(pi)         # 3.1415...
# Out:
# 5.0
# 3.141592653589793

# %% [markdown]
# 3. Renaming a module (alias):

# %%
import math as m
print(m.pow(2, 3))  # 8.0
# Out:
# 8.0

# %%
#First upload file in notebook and import it
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6ada41cf-370e-485c-bfb1-4b967e5cbe0d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6ada41cf-370e-485c-bfb1-4b967e5cbe0d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#What actually was there in my_universal_functions.py:

# def checkIfNotNumeric(*args):
#    returnVal = True
#    for x in args:
#     if not(isinstance(x, (int, float))):
#       return False
#    return True

# def addAllNumerics(*args):
#   s = 0
#   for x in args:
#     s += x
#   return s

# myName = "Python"

# %%
import my_universal_functions as muf

# %% [markdown]
# To check if file is present:

# %%
import os
print(os.listdir())  # Should list 'my_universal_functions.py'
# Out:
# ['.config', '__pycache__', 'my_universal_functions.py', '.ipynb_checkpoints', 'sample_data']

# %%
c = muf.addAllNumerics(2,3,4,6)
print(c)
# Out:
# 15

# %% [markdown]
# to import specific functions:

# %%
from my_universal_functions import checkIfNotNumeric, addAllNumerics, myName

print(checkIfNotNumeric(1, 2, "3"))     # Output: False
print(addAllNumerics(1, 2, 3))          # Output: 6
print(myName)                           # Output: Python
# Out:
# False
# 6
# Python

# %% [markdown]
# Import the entire module

# %%
import my_universal_functions as muf

print(muf.checkIfNotNumeric(1, 2.0))    # Output: True
print(muf.addAllNumerics(5, 5, 10))     # Output: 20
print(muf.myName)                       # Output: Python
# Out:
# True
# 20
# Python

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Data Structures

# %%
L = [1,3,4.9,"name",3]
T = (1,3,4.9,"name",3)
S = {1,3,4.9,"name",3}
D = {23:"twothree",'B':43,'C':'CCD'}

# %%
print("The type of L is ", type(L))
print("The type of T is ", type(T))
print("The type of S is ", type(S))
print("The type of D is ", type(D))
# Out:
# The type of L is  <class 'list'>
# The type of T is  <class 'tuple'>
# The type of S is  <class 'set'>
# The type of D is  <class 'dict'>

# %%
print(L[1])
print(T[1])
print(3 in S)
print(D[23])
# Out:
# 3
# 3
# True
# twothree

# %%
print(D['B'])
# Out:
# 43

# %%
S
# Out:
# {1, 3, 4.9, 'name'}

# %%
L
# Out:
# [1, 3, 4.9, 'name', 3]

# %%
L[1:3]
# Out:
# [3, 4.9]

# %%
L[::-1]
# Out:
# [3, 'name', 4.9, 3, 1]

# %%
T[:3]
# Out:
# (1, 3, 4.9)

# %%
L
# Out:
# [1, 3, 4.9, 'name', 3]

# %%
L = L + ["how","are",6,"you"]

# %%
L
# Out:
# [1, 3, 4.9, 'name', 3, 'how', 'are', 6, 'you']

# %%
L.append(6.8)

# %%
L
# Out:
# [1, 3, 4.9, 'name', 3, 'how', 'are', 6, 'you', 6.8]

# %%
T2 = ('a','b',45)
T3 = T+T2

# %%
T3
# Out:
# (1, 3, 4.9, 'name', 3, 'a', 'b', 45)

# %%
S
# Out:
# {1, 3, 4.9, 'name'}

# %%
S.add(56)

# %%
S
# Out:
# {1, 3, 4.9, 56, 'name'}

# %%
S.update({23,"game",1})

# %%
S
# Out:
# {1, 23, 3, 4.9, 56, 'game', 'name'}

# %%
D
# Out:
# {23: 'twothree', 'B': 43, 'C': 'CCD'}

# %%
D['newKey'] = "newValue"

# %%
D
# Out:
# {23: 'twothree', 'B': 43, 'C': 'CCD', 'newKey': 'newValue'}

# %%
D2 = {"y":"YY","z":10}

# %%
L
# Out:
# [1, 3, 4.9, 'name', 3, 'how', 'are', 6, 'you', 6.8]

# %%
del L[3]

# %%
L
# Out:
# [1, 3, 4.9, 3, 'how', 'are', 6, 'you', 6.8]

# %%
S
# Out:
# {1, 23, 3, 4.9, 56, 'game', 'name'}

# %%
S.remove('game')

# %%
S
# Out:
# {1, 23, 3, 4.9, 56, 'name'}

# %%
D
# Out:
# {23: 'twothree', 'B': 43, 'C': 'CCD', 'newKey': 'newValue'}

# %%
del D['C']

# %%
D
# Out:
# {23: 'twothree', 'B': 43, 'newKey': 'newValue'}

# %%
D = D + D2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-02f7553b163b> in <module>
# ----> 1 D = D + D2
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
D.update(D2)

# %%
D
# Out:
# {23: 'twothree', 'B': 43, 'newKey': 'newValue', 'y': 'YY', 'z': 10}

# %%
L
# Out:
# [1, 3, 4.9, 3, 'how', 'are', 6, 'you', 6.8]

# %%
L2 = L

# %%
L2
# Out:
# [1, 3, 4.9, 3, 'how', 'are', 6, 'you', 6.8]

# %%
L2[2] = "four point nine"

# %%
L2
# Out:
# [1, 3, 'four point nine', 3, 'how', 'are', 6, 'you', 6.8]

# %%
L
# Out:
# [1, 3, 'four point nine', 3, 'how', 'are', 6, 'you', 6.8]

# %%
L2 = L.copy()

# %%
L2
# Out:
# [1, 3, 'four point nine', 3, 'how', 'are', 6, 'you', 6.8]

# %%
L2[2] = 4.9

# %%
L2
# Out:
# [1, 3, 4.9, 3, 'how', 'are', 6, 'you', 6.8]

# %%
L
# Out:
# [1, 3, 'four point nine', 3, 'how', 'are', 6, 'you', 6.8]

# %%
L
# Out:
# [1, 3, 'four point nine', 3, 'how', 'are', 6, 'you', 6.8]

# %%
L3 = L[1:5]

# %%
L3
# Out:
# [3, 'four point nine', 3, 'how']

# %%
L3[0] = "three"

# %%
L
# Out:
# [1, 3, 'four point nine', 3, 'how', 'are', 6, 'you', 6.8]

# %%
help(L.append)
# Out:
# Help on built-in function append:
#
# append(object, /) method of builtins.list instance
#     Append object to the end of the list.

# %%
L.clear?

# %%
L.pop?

# %%
L.reverse()

# %%
L
# Out:
# [6.8, 'you', 6, 'are', 'how', 3, 'four point nine', 3, 1]

# %%
L[::-1]
# Out:
# [1, 3, 'four point nine', 3, 'how', 'are', 6, 'you', 6.8]

# %%
D.items()
# Out:
# dict_items([(23, 'twothree'), ('B', 43), ('newKey', 'newValue'), ('y', 'YY'), ('z', 10)])

# %%
L
# Out:
# [6.8, 'you', 6, 'are', 'how', 3, 'four point nine', 3, 1]

# %%
T
# Out:
# (1, 3, 4.9, 'name', 3)

# %%
S
# Out:
# {1, 23, 3, 4.9, 56, 'name'}

# %%
D
# Out:
# {23: 'twothree', 'B': 43, 'newKey': 'newValue', 'y': 'YY', 'z': 10}

# %%
D2 = {'A':L,'B':T,'C':S,'D':D}

# %%
D2['A'][3]
# Out:
# 'are'

# %%
K = D2['D']

# %%
K
# Out:
# {23: 'twothree', 'B': 43, 'newKey': 'newValue', 'y': 'YY', 'z': 10}

# %%
for x in K:
    print(x,K[x])
# Out:
# 23 twothree
# B 43
# newKey newValue
# y YY
# z 10

# %%
L3 = [L,T,D,23,"game"]

# %%
type(L3[2])
# Out:
# dict

# %%
L3 = [x**2 for x in range(10)]

# %%
L3
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
S3 = {x**2 for x in range(2,20,3)}

# %%
S3
# Out:
# {4, 25, 64, 121, 196, 289}

# %%
D
# Out:
# {23: 'twothree', 'B': 43, 'newKey': 'newValue', 'y': 'YY', 'z': 10}

# %%
23 in D
# Out:
# True

# %%
43 in D
# Out:
# False

# %%
"""Let say you are a teacher and you have different student
records containing id of a student and the marks list in each subject
where different students have taken different number of subjects. All
these records are in hard copy. You want to enter all the data in computer
and want to compute the average marks of each student and display"""

def getDataFromUser():
    D = {}
    while True:
        studentId = input("Enter student ID: ")
        marksList = input("Enter the marks by comma separted values: ")
        moreStudents = input('Enter "no" to quit insertion: ')
        if studentId in D:
            print(studentId, "is already insterted")
        else:
            D[studentId] = marksList.split(",")
        if moreStudents.lower() == "no":
            return D

# %%
studentData = getDataFromUser()
# Out:
# Enter student ID: 12
# Enter the marks by comma separted values: 56,45,13
# Enter "no" to quit insertion: asdf
# Enter student ID: 45
# Enter the marks by comma separted values: 44,55,66,77,4
# Enter "no" to quit insertion: asdfa
# Enter student ID: 12
# Enter the marks by comma separted values: 45,45
# Enter "no" to quit insertion: asdfa
# 12 is already insterted
# Enter student ID: 23
# Enter the marks by comma separted values: 45,45
# Enter "no" to quit insertion: no

# %%
studentData
# Out:
# {'12': ['56', '45', '13'],
#  '45': ['44', '55', '66', '77', '4'],
#  '23': ['45', '45']}

# %%
def getAvgMarks(D):
    avgMarks = {}
    for x in D:
        L = D[x]
        s = 0
        for marks in L:
            s += int(marks)
        avgMarks[x] = s/len(L)
    return avgMarks

# %%
avgM = getAvgMarks(studentData)

# %%
avgM
# Out:
# {'12': 38.0, '45': 49.2, '23': 45.0}

# %%
for x in avgM:
    print("Student :",x,"got avg Marks as: ",avgM[x])
# Out:
# Student : 12 got avg Marks as:  38.0
# Student : 45 got avg Marks as:  49.2
# Student : 23 got avg Marks as:  45.0
